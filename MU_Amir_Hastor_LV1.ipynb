# %% [markdown]
# **Zadatak 1**

# %% [markdown]
# -Učitao sam dataset pomoću funkcije pd.read_csv() i pregledao prvih nekoliko redova (df.head()), čime sam se upoznao sa sadržajem podataka.
#
# -Odredio sam dimenzije skupa podataka korištenjem df.shape, što mi je dalo broj redova i kolona.
#
# -Analizirao sam strukturu podataka pomoću df.info() i df.describe() kako bih utvrdio tipove podataka, prisustvo praznih vrijednosti i osnovne statističke pokazatelje.
#
# -Ispitao sam svrhu svake kolone — od osnovnih informacija o zaposlenima (godine, spol, obrazovanje) do poslovnih karakteristika (odjel, plata, radni staž, prekovremeni rad).
#
# -Koristio sam Seaborn i Matplotlib za vizualizaciju podataka.

# %%
import pandas as pd
import numpy as np

# Učitavanje CSV datoteke u DataFrame
df = pd.read_csv("/content/attrition.csv")

# Prikaz prvih nekoliko redova (da vidiš strukturu)
df.head(8)
# Out:
#   Attrition     BusinessTravel  DailyRate              Department  \
# 0       Yes      Travel_Rarely       1102                     NaN
# 1        No  Travel_Frequently        279  Research & Development
# 2       Yes      Travel_Rarely       1373  Research & Development
# 3        No  Travel_Frequently       1392  Research & Development
# 4        No      Travel_Rarely        591  Research & Development
# 5        No  Travel_Frequently       1005  Research & Development
# 6        No      Travel_Rarely       1324  Research & Development
# 7        No      Travel_Rarely       1358  Research & Development
#
#    DistanceFromHome Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1   College  Life Sciences              1               1
# 1                 8         1  Life Sciences              1               2
# 2                 2   College          Other              1               4
# ...

# %%
rows, cols = df.shape
print(f"Broj redova: {rows}")
print(f"Broj kolona: {cols}")
# Out:
# Broj redova: 1470
# Broj kolona: 35

# %%
# Statistički opis numeričkih kolona
df.describe()
# Out:
#          DailyRate  DistanceFromHome  EmployeeCount  EmployeeNumber  \
# count  1470.000000       1470.000000         1470.0     1470.000000
# mean    802.485714          9.192517            1.0     1024.865306
# std     403.509100          8.106864            0.0      602.024335
# min     102.000000          1.000000            1.0        1.000000
# 25%     465.000000          2.000000            1.0      491.250000
# 50%     802.000000          7.000000            1.0     1020.500000
# 75%    1157.000000         14.000000            1.0     1555.750000
# max    1499.000000         29.000000            1.0     2068.000000
#
#          HourlyRate  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count  1.470000e+03    1470.000000   1470.000000         1470.000000
# mean   5.837614e+41    6502.931293  14313.103401            2.693197
# std    3.258738e+42    4707.956783   7117.786044            2.498009
# min    1.068647e+13    1009.000000   2094.000000            0.000000
# ...

# %%
df.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'BirthDate'],
#       dtype='object')

# %%
df.tail(3)
# Out:
#      Attrition     BusinessTravel  DailyRate              Department  \
# 1467        No      Travel_Rarely        155  Research & Development
# 1468        No  Travel_Frequently       1023                   Sales
# 1469        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome Education EducationField  EmployeeCount  \
# 1467                 4  Bachelor  Life Sciences              1
# 1468                 2  Bachelor        Medical              1
# 1469                 8  Bachelor        Medical              1
#
#       EmployeeNumber EnvironmentSatisfaction  ... StandardHours  \
# 1467            2064                       2  ...          80.0
# 1468            2065               Very High  ...          80.0
# 1469            2068                       2  ...           NaN
#
#       StockOptionLevel TotalWorkingYears TrainingTimesLastYear  \
# 1467                 1                 6                   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1355 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   object
#  6   EducationField            1352 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   object
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   float64
#  12  JobInvolvement            1470 non-null   object
# ...

# %%
df.dtypes
# Out:
# Attrition                    object
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                    object
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction      object
# Gender                       object
# HourlyRate                  float64
# JobInvolvement               object
# JobLevel                     object
# JobRole                      object
# JobSatisfaction              object
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating            object
# RelationshipSatisfaction     object
# StandardHours               float64
# ...

# %%
df['BirthDate']
# Out:
# 0       1978-05-24
# 1       1970-05-24
# 2       1982-05-24
# 3       1986-05-24
# 4       1992-05-23
#            ...
# 1465    1983-05-24
# 1466    1980-05-23
# 1467    1992-05-23
# 1468    1970-05-24
# 1469    1985-05-24
# Name: BirthDate, Length: 1470, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram za distribuciju godina zaposlenika
sns.histplot(df['YearsAtCompany'], bins=10)
plt.title("Distribucija broja godina u kompaniji")
plt.xlabel("Godine u kompaniji")
plt.ylabel("Broj zaposlenika")
plt.show()
